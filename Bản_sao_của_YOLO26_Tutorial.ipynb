# %% [markdown]
# <a href="https://colab.research.google.com/github/NTDanh1C/Testing/blob/main/B%E1%BA%A3n_sao_c%E1%BB%A7a_YOLO26_Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !uv pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.35 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 43.3/112.6 GB disk)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="hILV0BfpTzO9KPW8qcww")
project = rf.workspace("danhalts-workspace").project("test2-cftje")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to test2-1 in yolov11:: 100%|██████████| 10/10 [00:00<00:00, 920.35it/s]

# %%
# Train YOLO26n on COCO8 for 3 epochs
# !yolo train model=yolo26n.pt data=/content/test2-1/data.yaml epochs=100 imgsz=640
# Out:
# ...
# Ultralytics 8.4.35 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolo26n.pt')  # load a pretrained model (recommended for training)

# Use the model

results = model('https://ultralytics.com/images/bus.jpg')  # predict on an image
